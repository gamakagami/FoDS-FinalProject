# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("ggplot")

df = pd.read_csv("merged_cleaned.csv")

# %%
histogram = df["Average_Engagement_Rate"].plot(kind="hist", bins = 40, title="Average Engagement Rate Histogram (All Data)", edgecolor="Black")
histogram.set_xlabel("Average Engagement Rate")
plt.show()

# %%
df_nano = df[df["Followers"] <= 10000]

histogram = df_nano["Average_Engagement_Rate"].plot(kind="hist", bins = 40, title="Average Engagement Rate Histogram (Nano)", edgecolor="Black")
histogram.set_xlabel("Average Engagement Rate")

plt.show()

# %%
df_micro = df[(df["Followers"] >= 10000) & (df["Followers"] <= 100000)]

histogram = df_micro["Average_Engagement_Rate"].plot(kind="hist", bins = 40, title="Average Engagement Rate Histogram (Nano)", edgecolor="Black")
histogram.set_xlabel("Average Engagement Rate")
plt.show()

# %%
df_macro = df[(df["Followers"] >= 100000) & (df["Followers"] <= 1000000)]

histogram = df_macro["Average_Engagement_Rate"].plot(kind="hist", bins = 40, title="Average Engagement Rate Histogram (Macro)", edgecolor="Black")
histogram.set_xlabel("Average Engagement Rate")
plt.show()

# %%
df_mega = df[(df["Followers"] >= 1000000)]

histogram = df_mega["Average_Engagement_Rate"].plot(kind="hist", bins = 40, title="Average Engagement Rate Histogram (Mega)", edgecolor="Black")
histogram.set_xlabel("Average Engagement Rate")
plt.show()

# %%
df_global = pd.read_csv("Global_Data.csv")

histogram = df_global["Average_Engagement_Rate"].plot(kind="hist", bins = 40, title="Average Engagement Rate Histogram (Global)", edgecolor="Black")
histogram.set_xlabel("Average Engagement Rate")
plt.show()

# %%
df_global = pd.read_csv("Indonesia_Data.csv")

histogram = df_global["Average_Engagement_Rate"].plot(kind="hist", bins = 40, title="Average Engagement Rate Histogram (Indonesia)", edgecolor="Black")
histogram.set_xlabel("Average Engagement Rate")
plt.show()
